# %%
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import HTML
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from scipy import special
from scipy.stats import probplot
from tqdm import tqdm

# %%
N = 20000

# %%
x = np.random.randn(5)
W = np.random.randn(5, N)
H = x @ W

# %%
B = np.random.randn(N, N)

# %%
k = 1000

# %%
for _ in tqdm(range(k)):
    S = special.expit(H)
    H = S @ B / np.sqrt(N)
# Out:
# 100%|██████████| 1000/1000 [01:13<00:00, 13.53it/s]

# %%
sns.kdeplot(H, label="k=1000")
plt.legend()

# %%
fig, ax = plt.subplots()
probplot(H, plot=ax)
# Out:
# ((array([-3.97862997, -3.7624649 , -3.64418052, ...,  3.64418052,
#           3.7624649 ,  3.97862997]),
#   array([-2.00912716, -1.90275318, -1.83652746, ...,  1.94993006,
#           1.99247532,  2.05400136])),
#  (0.5137285861192183, 0.0026449765149596997, 0.9999726299745307))
